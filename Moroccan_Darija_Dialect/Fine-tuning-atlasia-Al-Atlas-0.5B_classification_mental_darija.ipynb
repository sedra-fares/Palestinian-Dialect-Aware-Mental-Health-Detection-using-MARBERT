# %% [markdown]
# ### Installation

# %%
# %%capture
# import os, re
# if "COLAB_" not in "".join(os.environ.keys()):
#     !pip install unsloth  # Do this in local & cloud setups
# else:
#     import torch; v = re.match(r'[\d]{1,}\.[\d]{1,}', str(torch.__version__)).group(0)
#     xformers = 'xformers==' + {'2.10':'0.0.34','2.9':'0.0.33.post1','2.8':'0.0.32.post2'}.get(v, "0.0.34")
#     !pip install sentencepiece protobuf "datasets==4.3.0" "huggingface_hub>=0.34.0" hf_transfer
#     !pip install --no-deps unsloth_zoo bitsandbytes accelerate {xformers} peft trl triton unsloth
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2

# %%
# !pip install unsloth==2026.1.4
# !pip install -U transformers
# Out:
# Collecting unsloth==2026.1.4
#   Downloading unsloth-2026.1.4-py3-none-any.whl.metadata (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.5 MB/s eta 0:00:00
# Collecting unsloth_zoo>=2026.1.4 (from unsloth==2026.1.4)
#   Downloading unsloth_zoo-2026.2.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: wheel>=0.42.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (0.43.0)
# Requirement already satisfied: packaging in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (25.0)
# Requirement already satisfied: torch>=2.4.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (2.10.0)
# Requirement already satisfied: torchvision in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (0.25.0)
# Requirement already satisfied: numpy in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (2.2.5)
# Requirement already satisfied: tqdm in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (4.67.1)
# Requirement already satisfied: psutil in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (7.0.0)
# Collecting tyro (from unsloth==2026.1.4)
#   Downloading tyro-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: protobuf in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (6.33.5)
# Collecting bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 (from unsloth==2026.1.4)
#   Downloading bitsandbytes-0.49.1-py3-none-macosx_14_0_arm64.whl.metadata (10 kB)
# Collecting sentencepiece>=0.2.0 (from unsloth==2026.1.4)
#   Downloading sentencepiece-0.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth==2026.1.4)
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Collecting accelerate>=0.34.1 (from unsloth==2026.1.4)
#   Using cached accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting peft!=0.11.0,>=0.18.0 (from unsloth==2026.1.4)
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth==2026.1.4) (1.4.1)
# Collecting hf_transfer (from unsloth==2026.1.4)
#   Downloading hf_transfer-0.1.9-cp38-abi3-macosx_11_0_arm64.whl.metadata (1.7 kB)
# Collecting diffusers (from unsloth==2026.1.4)
#   Downloading diffusers-0.36.0-py3-none-any.whl.metadata (20 kB)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3 (from unsloth==2026.1.4)
#   Using cached transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth==2026.1.4)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth==2026.1.4) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth==2026.1.4) (0.7.0)
# Requirement already satisfied: filelock in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (3.20.3)
# Collecting pyarrow>=21.0.0 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading pyarrow-23.0.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.0 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (0.28.1)
# Collecting xxhash (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading xxhash-3.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.9.0,>=2023.1.0 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth==2026.1.4) (1.2.0)
# Requirement already satisfied: shellingham in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth==2026.1.4) (1.5.4)
# Requirement already satisfied: typer-slim in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth==2026.1.4) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from huggingface_hub>=0.34.0->unsloth==2026.1.4) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from torch>=2.4.0->unsloth==2026.1.4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from torch>=2.4.0->unsloth==2026.1.4) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from torch>=2.4.0->unsloth==2026.1.4) (3.1.6)
# Collecting huggingface_hub>=0.34.0 (from unsloth==2026.1.4)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth==2026.1.4) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth==2026.1.4) (0.22.2)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.1.4->unsloth==2026.1.4)
#   Downloading torchao-0.16.0-py3-none-any.whl.metadata (20 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.1.4->unsloth==2026.1.4)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from unsloth_zoo>=2026.1.4->unsloth==2026.1.4) (12.0.0)
# Collecting msgspec (from unsloth_zoo>=2026.1.4->unsloth==2026.1.4)
#   Downloading msgspec-0.20.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: importlib_metadata in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from diffusers->unsloth==2026.1.4) (8.7.0)
# Collecting docstring-parser>=0.15 (from tyro->unsloth==2026.1.4)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting typeguard>=4.0.0 (from tyro->unsloth==2026.1.4)
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading aiohttp-3.13.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: anyio in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (4.12.1)
# Requirement already satisfied: certifi in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (1.0.9)
# Requirement already satisfied: idna in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth==2026.1.4) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from importlib_metadata->diffusers->unsloth==2026.1.4) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth==2026.1.4) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (2025.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading frozenlist-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading multidict-6.7.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading propcache-0.4.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4)
#   Downloading yarl-1.22.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth==2026.1.4) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /Users/moujar/miniconda3/envs/3.10/lib/python3.10/site-packages (from typer-slim->huggingface_hub>=0.34.0->unsloth==2026.1.4) (8.3.1)
# Downloading unsloth-2026.1.4-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.7/405.7 kB 7.4 MB/s eta 0:00:007 MB/s eta 0:00:01
# Using cached accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading bitsandbytes-0.49.1-py3-none-macosx_14_0_arm64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 4.9 MB/s eta 0:00:00
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 5.2 MB/s eta 0:00:00 MB/s eta 0:00:01m
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 6.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading sentencepiece-0.2.1-cp310-cp310-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.8 MB/s eta 0:00:00 MB/s eta 0:00:01m
# Using cached transformers-4.57.6-py3-none-any.whl (12.0 MB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 8.3 MB/s eta 0:00:0012.2 MB/s eta 0:00:01
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 7.7 MB/s eta 0:00:009.6 MB/s eta 0:00:01
# Downloading unsloth_zoo-2026.2.1-py3-none-any.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.5/376.5 kB 2.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading diffusers-0.36.0-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading hf_transfer-0.1.9-cp38-abi3-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.6 MB/s eta 0:00:0011.9 MB/s eta 0:00:01
# Downloading tyro-1.0.6-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 4.0 MB/s eta 0:00:007 MB/s eta 0:00:01
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 5.5 MB/s eta 0:00:000:00:01
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.8 MB/s eta 0:00:00
# Downloading pyarrow-23.0.0-cp310-cp310-macosx_12_0_arm64.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading torchao-0.16.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.20.0-cp310-cp310-macosx_11_0_arm64.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 4.7 MB/s eta 0:00:000:00:01
# Downloading xxhash-3.6.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Downloading aiohttp-3.13.3-cp310-cp310-macosx_11_0_arm64.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.1/491.1 kB 6.0 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-macosx_11_0_arm64.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 2.4 MB/s eta 0:00:00
# Downloading multidict-6.7.1-cp310-cp310-macosx_11_0_arm64.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.3 MB/s eta 0:00:00
# Downloading propcache-0.4.1-cp310-cp310-macosx_11_0_arm64.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.7 MB/s eta 0:00:00
# Downloading yarl-1.22.0-cp310-cp310-macosx_11_0_arm64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: torchao, xxhash, typeguard, sentencepiece, pyarrow, propcache, multidict, msgspec, hf_transfer, fsspec, frozenlist, docstring-parser, dill, attrs, async-timeout, aiohappyeyeballs, yarl, tyro, multiprocess, huggingface_hub, aiosignal, cut_cross_entropy, bitsandbytes, aiohttp, accelerate, transformers, diffusers, peft, datasets, trl, unsloth_zoo, unsloth
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device

# %%
# !pip install modelscope
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /usr/local/lib/python3.12/dist-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (26.0rc2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)

# %%
# import unsloth

# %% [markdown]
# ### Unsloth
#
# `FastModel` supports loading nearly any model now! This includes Vision and Text models!

# %%
from unsloth import FastModel
from transformers import AutoModelForSequenceClassification
import torch

# Disable fast generation for bert!
# %env UNSLOTH_DISABLE_FAST_GENERATION = 1
import os; os.environ['UNSLOTH_USE_MODELSCOPE'] = '1'
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Llama-3.1-70B-bnb-4bit",
    "unsloth/Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

# id2label = {0: "sadness", 1: "joy", 2: "love", 3: "anger",4: "fear",5: "surprise"}
#
# label2id = {"sadness": 0, "joy": 1, "love": 2, "anger": 3, "fear": 4, "surprise": 5}
id2label = {0: 'Anxiety', 1: 'Normal', 2: 'Depression', 3: 'Suicidal', 4: 'Stress', 5: 'Bipolar', 6: 'Personality disorder'}

label2id = {'Anxiety': 0, 'Normal': 1, 'Depression': 2, 'Suicidal': 3, 'Stress': 4, 'Bipolar': 5, 'Personality disorder': 6}

model, tokenizer = FastModel.from_pretrained(
    model_name = "atlasia/Al-Atlas-0.5B",
    auto_model = AutoModelForSequenceClassification,
    max_seq_length = max_seq_length,
    dtype = dtype,
    num_labels  = 7,
    # full_finetuning = True,
    id2label = id2label,
    label2id = label2id,
    load_in_4bit = load_in_4bit,
    token = "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",
    device_map = "balanced"
    # token = "YOUR_HF_TOKEN", # HF Token for gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-02-12 12:44:26.752877: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770900266.974854      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770900267.038240      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770900267.567484      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770900267.567520      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770900267.567523      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770900267.567525      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# env: UNSLOTH_DISABLE_FAST_GENERATION=1
# ==((====))==  Unsloth 2026.1.4: Fast Qwen2 patching. Transformers: 4.57.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Some weights of Qwen2ForSequenceClassification were not initialized from the model checkpoint at atlasia/Al-Atlas-0.5B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/7.26k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# atlasia/Al-Atlas-0.5B does not have a padding token! Will use pad_token = <|vision_pad|>.

# %% [markdown]
# We now add LoRA adapters so we only need to update a small amount of parameters!

# %%
model = FastModel.get_peft_model(
    model,
    r = 64, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
      target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    task_type = "SEQ_CLS",
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients
# Unsloth: Upcasting `base_model.model.score` from float16 to float32 since it's in `modules_to_save`. Also allowing gradients.

# %%
from datasets import load_dataset,   Dataset
import pandas as pd

df = pd.read_csv("hf://datasets/moujar/MentalHealth-Darija/data.csv")
# Load the IMDB dataset
dataset = Dataset.from_pandas(df)
dataset
# Out:
# Dataset({
#     features: ['text_en', 'text', 'label'],
#     num_rows: 51093
# })

# %%
# dataset = Dataset.from_pandas(data)
# Split into training and validation sets
dataset = dataset.train_test_split(test_size = 0.1, seed=1337)

def tokenize_function(examples):
    return tokenizer(examples["text"], padding=True, truncation=True)

# # Apply the tokenizer to the dataset
train_dataset = dataset['train'].map(tokenize_function, batched = True)
val_dataset = dataset["test"].map(tokenize_function, batched = True)
# Out:
# Map:   0%|          | 0/45983 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5110 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text_en', 'text', 'label', 'input_ids', 'attention_mask'],
#     num_rows: 45983
# })

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text', 'label'],
#         num_rows: 45983
#     })
#     test: Dataset({
#         features: ['text_en', 'text', 'label'],
#         num_rows: 5110
#     })
# })

# %% [markdown]
# We compute **class weights** using scikit-learn’s ```compute_class_weight```.
# This is useful when training on datasets where certain classes are underrepresented, ensuring the model does not become biased towards majority labels.

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

labels = train_dataset["label"]
class_weights = compute_class_weight("balanced", classes = np.unique(labels), y = labels)

# %%
# We rename the dataset column from **`label`** to **`labels`**, since this is the expected field name for Hugging Face `Trainer`.
train_dataset = train_dataset.rename_column("label", "labels")
val_dataset = val_dataset.rename_column("label", "labels")

# %%
class_weights
# Out:
# array([2.02746914, 0.45557944, 0.48163355, 0.68821372, 3.1811138 ,
#        2.90022075, 8.10987654])

# %% [markdown]
# We define a `compute_metrics` function to evaluate the model during training.
# Here we use **accuracy** from scikit-learn, which compares predicted labels with the ground truth.
#
# **[NOTE]** Accuracy is a good baseline, but for imbalanced datasets you may also want to track metrics like **F1-score**, **precision**, or **recall**.

# %%
# from sklearn.metrics import accuracy_score

# def compute_metrics(eval_pred):
#     logits, labels = eval_pred
#     preds = logits.argmax(axis = -1)
#     return {"accuracy": accuracy_score(labels, preds)}
import numpy as np
from sklearn.metrics import f1_score

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    score = f1_score(labels, predictions, average="weighted")
    return {"f1": float(score)}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Hugging Face `Trainer`! More docs here: [Transformers docs](https://huggingface.co/docs/transformers/main_classes/trainer). We train for one full epoch (num_train_epochs=1) to get a meaningful result.

# %%
from transformers import TrainingArguments,Trainer
from unsloth import is_bfloat16_supported

trainer = Trainer(
    model = model,
    processing_class = tokenizer,
    eval_dataset = val_dataset,
    train_dataset = train_dataset,
    args = TrainingArguments(
        per_device_train_batch_size = 32,
        gradient_accumulation_steps = 1,
        warmup_steps = 5,
        num_train_epochs = 3, # bert-style models usually need more than 1 epoch
        # max_steps = 60,
        learning_rate = 5e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        eval_strategy = "steps",
        eval_steps = 0.10,  # Evaluate every 10% of total training steps
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use TrackIO/WandB etc
        # device_map = "balanced"
    ),
    compute_metrics = compute_metrics,
)

# %%
# trainer.train(resume_from_checkpoint = True)

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 2
#    \\   /|    Num examples = 45,983 | Num Epochs = 3 | Total steps = 4,311
# O^O/ \_/ \    Batch size per device = 32 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (32 x 1 x 1) = 32
#  "-____-"     Trainable parameters = 35,199,104 of 529,238,144 (6.65% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='4311' max='4311' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4311/4311 6:36:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>432</td>
#       <td>1.001400</td>
#       <td>0.768073</td>
#       <td>0.690015</td>
#     </tr>
#     <tr>
#       <td>864</td>
#       <td>0.570400</td>
#       <td>0.671773</td>
#       <td>0.729374</td>
#     </tr>
#     <tr>
#       <td>1296</td>
#       <td>0.547200</td>
#       <td>0.657257</td>
#       <td>0.748928</td>
#     </tr>
#     <tr>
#       <td>1728</td>
#       <td>0.568400</td>
#       <td>0.593220</td>
#       <td>0.771627</td>
#     </tr>
#     <tr>
#       <td>2160</td>
#       <td>0.341700</td>
#       <td>0.574148</td>
#       <td>0.769334</td>
#     </tr>
#     <tr>
#       <td>2592</td>
#       <td>0.551600</td>
#       <td>0.576159</td>
#       <td>0.775779</td>
#     </tr>
#     <tr>
#       <td>3024</td>
#       <td>0.142800</td>
#       <td>0.587101</td>
#       <td>0.779864</td>
#     </tr>
#     <tr>
#       <td>3456</td>
#       <td>0.385100</td>
#       <td>0.613815</td>
#       <td>0.775247</td>
#     </tr>
#     <tr>
#       <td>3888</td>
#       <td>0.284800</td>
#       <td>0.598551</td>
#       <td>0.777824</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# Let's train the model! To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model !

# %%
from transformers import pipeline

sentence1 = "انا مقلق وقلقان هادي شهر دابا ا ولدي اش كتقصد"

classifier = pipeline("sentiment-analysis", model = model,tokenizer = tokenizer)

classifier(sentence1)

# %%
atlasia-Al-Atlas-0.5B

# %% [markdown]
# <a name="Save"></a>
# ### Saving finetuned models
# To save the final model, either use Hugging Face's `push_to_hub` for an online save or `save_pretrained` for a local save.

# %%
model.save_pretrained("atlasia-Al-Atlas-0.5B_64_3_classification_mental_darija") 
tokenizer.save_pretrained("atlasia-Al-Atlas-0.5B_64_3_classification_mental_darija")
model.push_to_hub("moujar/atlasia-Al-Atlas-0.5B_64_3_classification_mental_darija", token = HF_TOKEN) 
tokenizer.push_to_hub("moujar/atlasia-Al-Atlas-0.5B_46_3_classification_mental_darija", token = HF_TOKEN)
